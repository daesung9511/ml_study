# %%
import pandas as pd

# %%
titanic_df = pd.read_csv("titanic_train.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dic1 = {"name":["daesung","mok_sung","geum_sung"],
       "age":[25,26,27]}
data_df = pd.DataFrame(dic1,index=["one","two","three"], columns=["name","age","sex"])
print(data_df)
# Out:
#             name  age  sex
# one      daesung   25  NaN
# two     mok_sung   26  NaN
# three  geum_sung   27  NaN

# %%
titanic_df["Pclass"].value_counts().index.values
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_df[["Pclass","Age"]].head(10).sort_values(by="Age",ascending=True).shape
# Out:
# (10, 2)

# %%
print(data_df.to_dict())
# Out:
# {'name': {'one': 'daesung', 'two': 'mok_sung', 'three': 'geum_sung'}, 'age': {'one': 25, 'two': 26, 'three': 27}, 'sex': {'one': nan, 'two': nan, 'three': nan}}

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 15)

next_titanic_df = titanic_df.drop(["Parch","Sex"],axis=1,inplace=False)
next_titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass            Name   Age  SibSp          Ticket     Fare Cabin Embarked
# 0            1         0       3  Braund, Mr....  22.0      1       A/5 21171   7.2500   NaN        S
# 1            2         1       1  Cumings, Mr...  38.0      1        PC 17599  71.2833   C85        C
# 2            3         1       3  Heikkinen, ...  26.0      0  STON/O2. 31...   7.9250   NaN        S
# 3            4         1       1  Futrelle, M...  35.0      1          113803  53.1000  C123        S
# 4            5         0       3  Allen, Mr. ...  35.0      0          373450   8.0500   NaN        S

# %%
series = titanic_df['Pclass'].value_counts()
df = series.reset_index(inplace=False)
print(df)
# Out:
#    index  Pclass
# 0      3     491
# 1      1     216
# 2      2     184

# %%
titanic_df[titanic_df.PassengerId>250]
# Out:
#      PassengerId  Survived  Pclass            Name     Sex   Age  SibSp  Parch          Ticket      Fare        Cabin Embarked
# 250          251         0       3  Reed, Mr. J...    male   NaN      0      0          362316    7.2500          NaN        S
# 251          252         0       3  Strom, Mrs....  female  29.0      1      1          347054   10.4625           G6        S
# 252          253         0       1  Stead, Mr. ...    male  62.0      0      0          113514   26.5500          C87        S
# 253          254         0       3  Lobb, Mr. W...    male  30.0      1      0       A/5. 3336   16.1000          NaN        S
# 254          255         0       3  Rosblom, Mr...  female  41.0      0      2          370129   20.2125          NaN        S
# 255          256         1       3  Touma, Mrs....  female  29.0      0      2            2650   15.2458          NaN        C
# ...

# %%
data = {'Name': ['Chulmin', 'Eunkyung','Jinwoong','Soobeom'],
        'Year': [2011, 2016, 2015, 2015],
        'Gender': ['Male', 'Female', 'Male', 'Male']
       }
data_df = pd.DataFrame(data, index=['one','two','three','four'])
data_df
# Out:
#            Name  Year  Gender
# one     Chulmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# four    Soobeom  2015    Male

# %%
data_df.loc['two','Year']
# Out:
# 2016

# %%
data_df.iloc[0,0]
# Out:
# 'Chulmin'

# %%
titanic_df[['Name','Age']][titanic_df['Age'] > 60].head(3)
# Out:
#               Name   Age
# 33  Wheadon, Mr...  66.0
# 54  Ostby, Mr. ...  65.0
# 96  Goldschmidt...  71.0

# %%
titanic_df.groupby(by="Pclass")['Age'].agg(['min','max'])
# Out:
#          min   max
# Pclass
# 1       0.92  80.0
# 2       0.67  70.0
# 3       0.42  74.0

# %%
agg_format={'Age':['max','min'], 'SibSp':'sum', 'Fare':'mean'}
titanic_df.groupby('Pclass').agg(agg_format)
# Out:
#          Age       SibSp       Fare
#          max   min   sum       mean
# Pclass
# 1       80.0  0.92    90  84.154687
# 2       70.0  0.67    74  20.662183
# 3       74.0  0.42   302  13.675550

# %%
titanic_df['Age']=titanic_df['Age'].fillna(titanic_df['Age'].mean())
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
from sklearn.datasets import load_iris
import pandas as pd
iris = load_iris()
iris_data = iris.data

iris_label = iris.target

iris_df = pd.DataFrame(iris_data, columns=iris.feature_names)
iris_df['labels'] = iris.target

iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  labels
# 0             5.1                3.5               1.4                0.2         0
# 1             4.9                3.0               1.4                0.2         0
# 2             4.7                3.2               1.3                0.2         0
# 3             4.6                3.1               1.5                0.2         0
# 4             5.0                3.6               1.4                0.2         0
